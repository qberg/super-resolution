# %%
#Mounting the drive to the colab workspace.
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import os
root_path = r'/content/drive/My Drive/CS6350_project_SR/SRCNN/'

#Changing the root directory to the project folder.
os.chdir(root_path) 
#Sanity check.
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1jafeTc6gPAhwQR34TSbLt34BukEKL78S/CS6350_project_SR/SRCNN

# %%
# !python run_srcnn.py --model "/content/drive/My Drive/CS6350_project_SR/SRCNN/results/x3/trained_models/srcnn_x3_ep184.pth" \
                     --input_images_dir "/content/drive/My Drive/CS6350_project_SR/SRCNN/demo" \
                     --output_dir "/content/drive/My Drive/CS6350_project_SR/SRCNN/results/demo" \
                     --scale 3 \
                     --zoom True
# Out:
# [INFO] DEVICE: cuda
# [INFO] the network is being set in inference mode...Done
# [INFO] b1_blur image passed onto the network...
# Traceback (most recent call last):
#   File "run_srcnn.py", line 95, in <module>
#     output_image = model(input_image)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/content/drive/.shortcut-targets-by-id/1jafeTc6gPAhwQR34TSbLt34BukEKL78S/CS6350_project_SR/SRCNN/model.py", line 34, in forward
#     x   = self.conv1(x)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py", line 141, in forward
#     input = module(input)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
# ...

# %%
# !unzip ./demo/demo.zip
# Out:
# Archive:  ./demo/demo.zip
#   inflating: b1_blur.jpg
#   inflating: u1_blur.jpg
#   inflating: b3_blur.jpg
#   inflating: u2_blur.jpg
#   inflating: u3_blur.jpg
#   inflating: d2_blur.jpg
